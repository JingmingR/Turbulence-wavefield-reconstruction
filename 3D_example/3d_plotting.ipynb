# %%
import numpy as np
import pylops
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib as mpl

# %%
# D = np.load('/Volumes/backup/MSc/3d/original/fre_ND.npy')
# D = np.load('/Volumes/backup/MSc/3d/xinv_ir14_nomask_it1000.npy')
D1 = np.load('/Volumes/backup/MSc/3d/original/D_aftmask.npy')
# fre = np.load('/Volumes/backup/MSc/3d/fre_shift_q.npy')
# xinv = np.load('/Volumes/backup/MSc/3d/D_all_q.npy')
# mask = np.load('/Volumes/backup/MSc/3d/D_aftmask_q.npy')
# relative = np.load('/Volumes/backup/MSc/3d/relative_20iter.npy')
# relative_fre = np.load('/Volumes/backup/MSc/3d/relative_fre_20iter.npy')
data = np.load('/Volumes/backup/MSc/3d/xinv_ir14_it1000.npz')
D = data['xinv']
relative=data['relative']
idr = data['idr']

# %%
shot = 277

vmin = np.amin(D1[:,:,shot:shot+3])
vmax = np.amax(D1[:,:,shot:shot+3])

vmin_r = np.amin(relative[:,:,shot:shot+3])
vmax_r = np.amax(relative[:,:,shot:shot+3])

nt,nr,ns = D.shape

idr = np.arange(0,nr,3)

code_bar = np.zeros((1,nr))
code_bar_1 = np.zeros((3,nr))
code_bar_2 = np.zeros((3,nr))
code_bar_3 = np.zeros((3,nr))
code_bar_4 = np.zeros((3,nr))

code_bar[:,idr] = 1
if code_bar[:,shot]==1:
    code_bar_1[:,idr]=1
if code_bar[:,shot+1]==1:
    code_bar_2[:,idr]=1
if code_bar[:,shot+2]==1:
    code_bar_3[:,idr]=1
if code_bar[:,shot+3]==1:
    code_bar_4[:,idr]=1
    
fig = plt.figure(figsize = (30,20))

gs0 = gridspec.GridSpec(1, 4)
gs0.update(top=0.98, bottom=0.96)
bar0 = plt.subplot(gs0[0])
bar1 = plt.subplot(gs0[1])
bar2 = plt.subplot(gs0[2])
bar3 = plt.subplot(gs0[3])
bar0.imshow(code_bar_1,cmap='gray',aspect='auto')
bar0.set_xticklabels([])
bar0.set_yticklabels([])
bar1.imshow(code_bar_2,cmap='gray',aspect='auto')
bar1.set_xticklabels([])
bar1.set_yticklabels([])
bar2.imshow(code_bar_3,cmap='gray',aspect='auto')
bar2.set_xticklabels([])
bar2.set_yticklabels([])
bar3.imshow(code_bar_3,cmap='gray',aspect='auto')
bar3.set_xticklabels([])
bar3.set_yticklabels([])
gs = gridspec.GridSpec(1, 4)
gs.update(top=0.52, bottom=0.15,wspace=0.15)
ax1 = plt.subplot(gs[0])
ax2 = plt.subplot(gs[1])
ax0 = plt.subplot(gs[2])
ax01 = plt.subplot(gs[3])

gs2 = gridspec.GridSpec(1, 4)
gs2.update(top=0.96, bottom=0.55)
ax3 = plt.subplot(gs2[0])
ax4 = plt.subplot(gs2[1])
ax5 = plt.subplot(gs2[2])
ax6 = plt.subplot(gs2[3])

ax3.imshow(D1[:,:,shot],cmap='gray',aspect='auto',vmin=vmin, vmax=vmax)
ax3.set_xlabel('Receiver number', fontsize=20)
ax3.set_ylabel('Time sample', fontsize=20)
ax4.imshow(D1[:,:,shot+1],cmap='gray',aspect='auto',vmin=vmin, vmax=vmax)
ax5.imshow(D1[:,:,shot+2],cmap='gray',aspect='auto',vmin=vmin, vmax=vmax)
ax6.imshow(D1[:,:,shot+3],cmap='gray',aspect='auto',vmin=vmin, vmax=vmax)

ax1.imshow(D[:,:,shot],cmap='gray',aspect='auto',vmin=vmin, vmax=vmax)
ax1.set_xlabel('Receiver number', fontsize=20)
ax1.set_ylabel('Time sample', fontsize=20)

ax2.imshow(D[:,:,shot+1],cmap='gray',aspect='auto',vmin=vmin, vmax=vmax)
ax2.set_xlabel('Receiver number', fontsize=20)
ax2.set_ylabel('Time sample', fontsize=20)

ax0.imshow(D[:,:,shot+2],cmap='gray',aspect='auto',vmin=vmin, vmax=vmax)
ax0.set_xlabel('Receiver number', fontsize=20)
ax0.set_ylabel('Time sample', fontsize=20)

im = ax01.imshow(D[:,:,shot+3],cmap='gray',aspect='auto',vmin=vmin, vmax=vmax)
ax01.set_xlabel('Receiver number', fontsize=20)
ax01.set_ylabel('Time sample', fontsize=20)


# cbar.ax.tick_params(labelsize=12) 

plt.show()
# fig.savefig('3d.eps', format='eps', dpi=100,bbox_inches='tight')

# %%
rec = 150

fig = plt.figure(figsize = (30,30))
gs = gridspec.GridSpec(1, 3)
gs.update(top=0.48, bottom=0.05,wspace=0.15)
ax1 = plt.subplot(gs[0])
ax2 = plt.subplot(gs[1])
ax0 = plt.subplot(gs[2])

gs2 = gridspec.GridSpec(1, 3)
gs2.update(top=0.98, bottom=0.55)
ax3 = plt.subplot(gs2[0])
ax4 = plt.subplot(gs2[1])
ax5 = plt.subplot(gs2[2])

ax3.imshow(D[:,rec,:],cmap='gray',aspect='auto')
ax3.set_xlabel('Shot number', fontsize=20)
ax3.set_ylabel('Time sample', fontsize=20)
ax4.imshow(D[:,rec+1,:],cmap='gray',aspect='auto')
ax5.imshow(D[:,rec+2,:],cmap='gray',aspect='auto')

ax1.imshow(D1[:,rec,:],cmap='gray',aspect='auto')
ax1.set_xlabel('Shot number', fontsize=20)
ax1.set_ylabel('Time sample', fontsize=20)

ax2.imshow(D1[:,rec+1,:],cmap='gray',aspect='auto')
ax2.set_xlabel('Shot number', fontsize=20)
ax2.set_ylabel('Time sample', fontsize=20)

ax0.imshow(D1[:,rec+2,:],cmap='gray',aspect='auto')
ax0.set_xlabel('Shot number', fontsize=20)
ax0.set_ylabel('Time sample', fontsize=20)
# im1 = ax2.imshow(relative[:,rec,:],cmap='gray',aspect='auto')

# cbar = plt.colorbar(im1, cax=axc)
# cbar.ax.tick_params(labelsize=12) 

plt.show()

# %%
shot = 140

vmin = np.amin(D1[:,:,shot:shot+7])
vmax = np.amax(D1[:,:,shot:shot+7])

nt,nr,ns = D.shape
code_bar = np.zeros((1,nr))
code_bar_1 = np.zeros((3,nr))
code_bar_2 = np.zeros((3,nr))
code_bar_3 = np.zeros((3,nr))
code_bar_4 = np.zeros((3,nr))
code_bar_5 = np.zeros((3,nr))
code_bar_6 = np.zeros((3,nr))
code_bar_7 = np.zeros((3,nr))
code_bar_8 = np.zeros((3,nr))

code_bar[:,idr] = 1
if code_bar[:,shot]==1:
    code_bar_1[:,idr]=1
if code_bar[:,shot+1]==1:
    code_bar_2[:,idr]=1
if code_bar[:,shot+2]==1:
    code_bar_3[:,idr]=1
if code_bar[:,shot+3]==1:
    code_bar_4[:,idr]=1
if code_bar[:,shot+4]==1:
    code_bar_5[:,idr]=1
if code_bar[:,shot+5]==1:
    code_bar_6[:,idr]=1
if code_bar[:,shot+6]==1:
    code_bar_7[:,idr]=1
if code_bar[:,shot+7]==1:
    code_bar_8[:,idr]=1    
fig = plt.figure(figsize = (30,20))

gs0 = gridspec.GridSpec(1, 4,wspace=0.15)
gs0.update(top=0.97, bottom=0.95)
bar0 = plt.subplot(gs0[0])
bar1 = plt.subplot(gs0[1])
bar2 = plt.subplot(gs0[2])
bar3 = plt.subplot(gs0[3])
bar0.imshow(code_bar_1,cmap='gray',aspect='auto')
bar0.set_title('a)',y=1,fontsize=30)
bar0.set_xticklabels([])
bar0.set_yticklabels([])
bar1.imshow(code_bar_2,cmap='gray',aspect='auto')
bar1.set_title('b)',y=1,fontsize=30)
bar1.set_xticklabels([])
bar1.set_yticklabels([])
bar2.imshow(code_bar_3,cmap='gray',aspect='auto')
bar2.set_title('c)',y=1,fontsize=30)
bar2.set_xticklabels([])
bar2.set_yticklabels([])
bar3.imshow(code_bar_4,cmap='gray',aspect='auto')
bar3.set_title('d)',y=1,fontsize=30)
bar3.set_xticklabels([])
bar3.set_yticklabels([])

gs01 = gridspec.GridSpec(1, 4,wspace=0.15)
gs01.update(top=0.47, bottom=0.45)
bar4 = plt.subplot(gs01[0])
bar5 = plt.subplot(gs01[1])
bar6 = plt.subplot(gs01[2])
bar7 = plt.subplot(gs01[3])
bar4.imshow(code_bar_5,cmap='gray',aspect='auto')
bar4.set_title('e)',y=1,fontsize=30)
bar4.set_xticklabels([])
bar4.set_yticklabels([])
bar5.imshow(code_bar_6,cmap='gray',aspect='auto')
bar5.set_title('f)',y=1,fontsize=30)
bar5.set_xticklabels([])
bar5.set_yticklabels([])
bar6.imshow(code_bar_7,cmap='gray',aspect='auto')
bar6.set_title('g)',y=1,fontsize=30)
bar6.set_xticklabels([])
bar6.set_yticklabels([])
bar7.imshow(code_bar_8,cmap='gray',aspect='auto')
bar7.set_title('h)',y=1,fontsize=30)
bar7.set_xticklabels([])
bar7.set_yticklabels([])


gs1 = gridspec.GridSpec(1, 4)
gs1.update(top=0.95, bottom=0.53,wspace=0.15)
ax0 = plt.subplot(gs1[0])
ax1 = plt.subplot(gs1[1])
ax2 = plt.subplot(gs1[2])
ax3 = plt.subplot(gs1[3])

gs2 = gridspec.GridSpec(1, 4)
gs2.update(top=0.45, bottom=0.03,wspace=0.15)
ax4 = plt.subplot(gs2[0])
ax5 = plt.subplot(gs2[1])
ax6 = plt.subplot(gs2[2])
ax7 = plt.subplot(gs2[3])

ax0.imshow(D[:,:,shot],cmap='gray',aspect='auto',vmin=vmin, vmax=vmax)
ax0.set_xlabel('Receiver number', fontsize=30)
ax0.set_ylabel('Time sample', fontsize=30)
ax0.tick_params(axis = 'both', which = 'major', labelsize = 20)
ax1.imshow(D[:,:,shot+1],cmap='gray',aspect='auto',vmin=vmin, vmax=vmax)
ax1.set_xticklabels([])
ax1.set_yticklabels([])
# ax1.set_title('b)',y=1,fontsize=30)
ax2.imshow(D[:,:,shot+2],cmap='gray',aspect='auto',vmin=vmin, vmax=vmax)
ax2.set_xticklabels([])
ax2.set_yticklabels([])
# ax2.set_title('c)',y=1,fontsize=30)
ax3.imshow(D[:,:,shot+3],cmap='gray',aspect='auto',vmin=vmin, vmax=vmax)
ax3.set_xticklabels([])
ax3.set_yticklabels([])
# ax3.set_title('d)',y=1,fontsize=30)
ax4.imshow(D[:,:,shot+4],cmap='gray',aspect='auto',vmin=vmin, vmax=vmax)
ax4.set_xlabel('Receiver number', fontsize=30)
ax4.set_ylabel('Time sample', fontsize=30)
ax4.tick_params(axis = 'both', which = 'major', labelsize = 20)
# ax4.set_title('e)',y=1,fontsize=30)
ax5.imshow(D[:,:,shot+5],cmap='gray',aspect='auto',vmin=vmin, vmax=vmax)
ax5.set_xticklabels([])
ax5.set_yticklabels([])
# ax5.set_title('f)',y=1,fontsize=30)
ax6.imshow(D[:,:,shot+6],cmap='gray',aspect='auto',vmin=vmin, vmax=vmax)
ax6.set_xticklabels([])
ax6.set_yticklabels([])
# ax6.set_title('g)',y=1,fontsize=30)
ax7.imshow(D[:,:,shot+7],cmap='gray',aspect='auto',vmin=vmin, vmax=vmax)
ax7.set_xticklabels([])
ax7.set_yticklabels([])
# ax7.set_title('h)',y=1,fontsize=30)
# cbar.ax.tick_params(labelsize=12) 

plt.show()
# fig.savefig('3d_shot_left.eps', format='eps', dpi=100,bbox_inches='tight')

# %%
# relative error
# shot = 0

vmin = np.amin(relative[:,:,shot:shot+7])
# vmax = np.amax(relative[:,:,shot:shot+7])
vmax = 0.6
nt,nr,ns = D.shape
code_bar = np.zeros((1,nr))
code_bar_1 = np.zeros((3,nr))
code_bar_2 = np.zeros((3,nr))
code_bar_3 = np.zeros((3,nr))
code_bar_4 = np.zeros((3,nr))
code_bar_5 = np.zeros((3,nr))
code_bar_6 = np.zeros((3,nr))
code_bar_7 = np.zeros((3,nr))
code_bar_8 = np.zeros((3,nr))

code_bar[:,idr] = 1
if code_bar[:,shot]==1:
    code_bar_1[:,idr]=1
if code_bar[:,shot+1]==1:
    code_bar_2[:,idr]=1
if code_bar[:,shot+2]==1:
    code_bar_3[:,idr]=1
if code_bar[:,shot+3]==1:
    code_bar_4[:,idr]=1
if code_bar[:,shot+4]==1:
    code_bar_5[:,idr]=1
if code_bar[:,shot+5]==1:
    code_bar_6[:,idr]=1
if code_bar[:,shot+6]==1:
    code_bar_7[:,idr]=1
if code_bar[:,shot+7]==1:
    code_bar_8[:,idr]=1    
fig = plt.figure(figsize = (30,20))

gs0 = gridspec.GridSpec(1, 4,wspace=0.15)
gs0.update(top=0.97, bottom=0.955)
bar0 = plt.subplot(gs0[0])
bar1 = plt.subplot(gs0[1])
bar2 = plt.subplot(gs0[2])
bar3 = plt.subplot(gs0[3])
bar0.imshow(code_bar_1,cmap='gray',aspect='auto')
bar0.set_title('a)',y=1,fontsize=30)
bar0.set_xticklabels([])
bar0.set_yticklabels([])
bar1.imshow(code_bar_2,cmap='gray',aspect='auto')
bar1.set_title('b)',y=1,fontsize=30)
bar1.set_xticklabels([])
bar1.set_yticklabels([])
bar2.imshow(code_bar_3,cmap='gray',aspect='auto')
bar2.set_title('c)',y=1,fontsize=30)
bar2.set_xticklabels([])
bar2.set_yticklabels([])
bar3.imshow(code_bar_4,cmap='gray',aspect='auto')
bar3.set_title('d)',y=1,fontsize=30)
bar3.set_xticklabels([])
bar3.set_yticklabels([])

gs01 = gridspec.GridSpec(1, 4,wspace=0.15)
gs01.update(top=0.47, bottom=0.455)
bar4 = plt.subplot(gs01[0])
bar5 = plt.subplot(gs01[1])
bar6 = plt.subplot(gs01[2])
bar7 = plt.subplot(gs01[3])
bar4.imshow(code_bar_5,cmap='gray',aspect='auto')
bar4.set_title('e)',y=1,fontsize=30)
bar4.set_xticklabels([])
bar4.set_yticklabels([])
bar5.imshow(code_bar_6,cmap='gray',aspect='auto')
bar5.set_title('f)',y=1,fontsize=30)
bar5.set_xticklabels([])
bar5.set_yticklabels([])
bar6.imshow(code_bar_7,cmap='gray',aspect='auto')
bar6.set_title('g)',y=1,fontsize=30)
bar6.set_xticklabels([])
bar6.set_yticklabels([])
bar7.imshow(code_bar_8,cmap='gray',aspect='auto')
bar7.set_title('h)',y=1,fontsize=30)
bar7.set_xticklabels([])
bar7.set_yticklabels([])


gs1 = gridspec.GridSpec(1, 4)
gs1.update(top=0.95, bottom=0.53,wspace=0.15)
ax0 = plt.subplot(gs1[0])
ax1 = plt.subplot(gs1[1])
ax2 = plt.subplot(gs1[2])
ax3 = plt.subplot(gs1[3])

gs2 = gridspec.GridSpec(1, 4)
gs2.update(top=0.45, bottom=0.03,wspace=0.15)
ax4 = plt.subplot(gs2[0])
ax5 = plt.subplot(gs2[1])
ax6 = plt.subplot(gs2[2])
ax7 = plt.subplot(gs2[3])

ax0.imshow(relative[:,:,shot],cmap='gray',aspect='auto',vmin=vmin, vmax=vmax)
ax0.set_xlabel('Receiver number', fontsize=30)
ax0.set_ylabel('Time sample', fontsize=30)
ax0.tick_params(axis = 'both', which = 'major', labelsize = 20)
ax1.imshow(relative[:,:,shot+1],cmap='gray',aspect='auto',vmin=vmin, vmax=vmax)
ax1.set_xticklabels([])
ax1.set_yticklabels([])
# ax1.set_title('b)',y=1,fontsize=30)
ax2.imshow(relative[:,:,shot+2],cmap='gray',aspect='auto',vmin=vmin, vmax=vmax)
ax2.set_xticklabels([])
ax2.set_yticklabels([])
# ax2.set_title('c)',y=1,fontsize=30)
ax3.imshow(relative[:,:,shot+3],cmap='gray',aspect='auto',vmin=vmin, vmax=vmax)
ax3.set_xticklabels([])
ax3.set_yticklabels([])
# ax3.set_title('d)',y=1,fontsize=30)
ax4.imshow(relative[:,:,shot+4],cmap='gray',aspect='auto',vmin=vmin, vmax=vmax)
ax4.set_xlabel('Receiver number', fontsize=30)
ax4.set_ylabel('Time sample', fontsize=30)
ax4.tick_params(axis = 'both', which = 'major', labelsize = 20)
# ax4.set_title('e)',y=1,fontsize=30)
ax5.imshow(relative[:,:,shot+5],cmap='gray',aspect='auto',vmin=vmin, vmax=vmax)
ax5.set_xticklabels([])
ax5.set_yticklabels([])
# ax5.set_title('f)',y=1,fontsize=30)
ax6.imshow(relative[:,:,shot+6],cmap='gray',aspect='auto',vmin=vmin, vmax=vmax)
ax6.set_xticklabels([])
ax6.set_yticklabels([])
# ax6.set_title('g)',y=1,fontsize=30)
im = ax7.imshow(relative[:,:,shot+7],cmap='gray',aspect='auto',vmin=vmin, vmax=vmax)
ax7.set_xticklabels([])
ax7.set_yticklabels([])
# ax7.set_title('h)',y=1,fontsize=30)

gsbar = gridspec.GridSpec(1, 1)
gsbar.update(left=0.905, right=0.915,top=0.97, bottom=0.03)
cax = plt.subplot(gsbar[0])
cbar = plt.colorbar(im, cax=cax)
cbar.ax.tick_params(labelsize=20) 
# cbar.ax.tick_params(labelsize=12) 

plt.show()
# fig.savefig('3d_shot_left_re.eps', format='eps', dpi=100,bbox_inches='tight')

# %%
shot = 0

vmin = np.amin(D1[:,:,shot:shot+2])
vmax = np.amax(D1[:,:,shot:shot+2])

nt,nr,ns = D.shape
code_bar = np.zeros((1,nr))
code_bar_1 = np.zeros((3,nr))
code_bar_2 = np.zeros((3,nr))
code_bar_3 = np.zeros((3,nr))


code_bar[:,idr] = 1
if code_bar[:,shot]==1:
    code_bar_1[:,idr]=1
if code_bar[:,shot+1]==1:
    code_bar_2[:,idr]=1
if code_bar[:,shot+2]==1:
    code_bar_3[:,idr]=1

fig = plt.figure(figsize = (30,20))

gs0 = gridspec.GridSpec(1, 3,wspace=0.15)
gs0.update(top=0.97, bottom=0.955)
bar0 = plt.subplot(gs0[0])
bar1 = plt.subplot(gs0[1])
bar2 = plt.subplot(gs0[2])
bar0.imshow(code_bar_1,cmap='gray',aspect='auto')
bar0.set_title('a)',y=1,fontsize=30)
bar0.set_xticklabels([])
bar0.set_yticklabels([])
bar1.imshow(code_bar_2,cmap='gray',aspect='auto')
bar1.set_title('b)',y=1,fontsize=30)
bar1.set_xticklabels([])
bar1.set_yticklabels([])
bar2.imshow(code_bar_3,cmap='gray',aspect='auto')
bar2.set_title('c)',y=1,fontsize=30)
bar2.set_xticklabels([])
bar2.set_yticklabels([])

gs01 = gridspec.GridSpec(1, 3,wspace=0.15)
gs01.update(top=0.47, bottom=0.455)
bar4 = plt.subplot(gs01[0])
bar5 = plt.subplot(gs01[1])
bar6 = plt.subplot(gs01[2])
bar4.imshow(code_bar_1,cmap='gray',aspect='auto')
bar4.set_xticklabels([])
bar4.set_yticklabels([])
bar5.imshow(code_bar_2,cmap='gray',aspect='auto')
bar5.set_xticklabels([])
bar5.set_yticklabels([])
bar6.imshow(code_bar_3,cmap='gray',aspect='auto')
bar6.set_xticklabels([])
bar6.set_yticklabels([])


gs1 = gridspec.GridSpec(1, 3)
gs1.update(top=0.95, bottom=0.53,wspace=0.15)
ax0 = plt.subplot(gs1[0])
ax1 = plt.subplot(gs1[1])
ax2 = plt.subplot(gs1[2])

gs2 = gridspec.GridSpec(1, 3)
gs2.update(top=0.45, bottom=0.03,wspace=0.15)
ax4 = plt.subplot(gs2[0])
ax5 = plt.subplot(gs2[1])
ax6 = plt.subplot(gs2[2])

ax0.imshow(D[:,:,shot],cmap='gray',aspect='auto',vmin=vmin, vmax=vmax)
ax0.set_xlabel('Receiver number', fontsize=30)
ax0.set_ylabel('Time sample', fontsize=30)
ax0.tick_params(axis = 'both', which = 'major', labelsize = 20)
ax1.imshow(D[:,:,shot+1],cmap='gray',aspect='auto',vmin=vmin, vmax=vmax)
ax1.set_xticklabels([])
ax1.set_yticklabels([])
# ax1.set_title('b)',y=1,fontsize=30)
ax2.imshow(D[:,:,shot+2],cmap='gray',aspect='auto',vmin=vmin, vmax=vmax)
ax2.set_xticklabels([])
ax2.set_yticklabels([])
# ax2.set_title('c)',y=1,fontsize=30)

vmin = np.amin(relative[:,:,shot:shot+2])
# vmax = np.amax(relative[:,:,shot:shot+7])
vmax = 0.6

ax4.imshow(relative[:,:,shot],cmap='gray',aspect='auto',vmin=vmin, vmax=vmax)
ax4.set_xlabel('Receiver number', fontsize=30)
ax4.set_ylabel('Time sample', fontsize=30)
ax4.tick_params(axis = 'both', which = 'major', labelsize = 20)
# ax4.set_title('e)',y=1,fontsize=30)
ax5.imshow(relative[:,:,shot+1],cmap='gray',aspect='auto',vmin=vmin, vmax=vmax)
ax5.set_xticklabels([])
ax5.set_yticklabels([])
# ax5.set_title('f)',y=1,fontsize=30)
ax6.imshow(relative[:,:,shot+2],cmap='gray',aspect='auto',vmin=vmin, vmax=vmax)
ax6.set_xticklabels([])
ax6.set_yticklabels([])
# ax6.set_title('g)',y=1,fontsize=30)
# cbar.ax.tick_params(labelsize=12) 

plt.show()
fig.savefig('3d_shot_nocross.eps', format='eps', dpi=100,bbox_inches='tight')

# %%
D=np.swapaxes(D,1,2)
D1=np.swapaxes(D1,1,2)
relative=np.swapaxes(relative,1,2)

# %%
shot = 270
vmin = np.amin(D1[:,:,shot:shot+7])
vmax = np.amax(D1[:,:,shot:shot+7])

nt,nr,ns = D.shape
code_bar = np.zeros((1,nr))
code_bar_1 = np.zeros((3,nr))
code_bar_2 = np.zeros((3,nr))
code_bar_3 = np.zeros((3,nr))
code_bar_4 = np.zeros((3,nr))
code_bar_5 = np.zeros((3,nr))
code_bar_6 = np.zeros((3,nr))
code_bar_7 = np.zeros((3,nr))
code_bar_8 = np.zeros((3,nr))

code_bar[:,idr] = 1
if code_bar[:,shot]==1:
    code_bar_1[:,idr]=1
if code_bar[:,shot+1]==1:
    code_bar_2[:,idr]=1
if code_bar[:,shot+2]==1:
    code_bar_3[:,idr]=1
if code_bar[:,shot+3]==1:
    code_bar_4[:,idr]=1
if code_bar[:,shot+4]==1:
    code_bar_5[:,idr]=1
if code_bar[:,shot+5]==1:
    code_bar_6[:,idr]=1
if code_bar[:,shot+6]==1:
    code_bar_7[:,idr]=1
if code_bar[:,shot+7]==1:
    code_bar_8[:,idr]=1    
fig = plt.figure(figsize = (30,20))

gs0 = gridspec.GridSpec(1, 4,wspace=0.15)
gs0.update(top=0.97, bottom=0.95)
bar0 = plt.subplot(gs0[0])
bar1 = plt.subplot(gs0[1])
bar2 = plt.subplot(gs0[2])
bar3 = plt.subplot(gs0[3])
bar0.imshow(code_bar_1,cmap='gray',aspect='auto')
bar0.set_title('a)',y=1,fontsize=30)
bar0.set_xticklabels([])
bar0.set_yticklabels([])
bar1.imshow(code_bar_2,cmap='gray',aspect='auto')
bar1.set_title('b)',y=1,fontsize=30)
bar1.set_xticklabels([])
bar1.set_yticklabels([])
bar2.imshow(code_bar_3,cmap='gray',aspect='auto')
bar2.set_title('c)',y=1,fontsize=30)
bar2.set_xticklabels([])
bar2.set_yticklabels([])
bar3.imshow(code_bar_4,cmap='gray',aspect='auto')
bar3.set_title('d)',y=1,fontsize=30)
bar3.set_xticklabels([])
bar3.set_yticklabels([])

gs01 = gridspec.GridSpec(1, 4,wspace=0.15)
gs01.update(top=0.47, bottom=0.45)
bar4 = plt.subplot(gs01[0])
bar5 = plt.subplot(gs01[1])
bar6 = plt.subplot(gs01[2])
bar7 = plt.subplot(gs01[3])
bar4.imshow(code_bar_5,cmap='gray',aspect='auto')
bar4.set_title('e)',y=1,fontsize=30)
bar4.set_xticklabels([])
bar4.set_yticklabels([])
bar5.imshow(code_bar_6,cmap='gray',aspect='auto')
bar5.set_title('f)',y=1,fontsize=30)
bar5.set_xticklabels([])
bar5.set_yticklabels([])
bar6.imshow(code_bar_7,cmap='gray',aspect='auto')
bar6.set_title('g)',y=1,fontsize=30)
bar6.set_xticklabels([])
bar6.set_yticklabels([])
bar7.imshow(code_bar_8,cmap='gray',aspect='auto')
bar7.set_title('h)',y=1,fontsize=30)
bar7.set_xticklabels([])
bar7.set_yticklabels([])


gs1 = gridspec.GridSpec(1, 4)
gs1.update(top=0.95, bottom=0.53,wspace=0.15)
ax0 = plt.subplot(gs1[0])
ax1 = plt.subplot(gs1[1])
ax2 = plt.subplot(gs1[2])
ax3 = plt.subplot(gs1[3])

gs2 = gridspec.GridSpec(1, 4)
gs2.update(top=0.45, bottom=0.03,wspace=0.15)
ax4 = plt.subplot(gs2[0])
ax5 = plt.subplot(gs2[1])
ax6 = plt.subplot(gs2[2])
ax7 = plt.subplot(gs2[3])

ax0.imshow(D[:,:,shot],cmap='gray',aspect='auto',vmin=vmin, vmax=vmax)
ax0.set_xlabel('Shot number', fontsize=30)
ax0.set_ylabel('Time sample', fontsize=30)
ax0.tick_params(axis = 'both', which = 'major', labelsize = 20)
ax1.imshow(D[:,:,shot+1],cmap='gray',aspect='auto',vmin=vmin, vmax=vmax)
ax1.set_xticklabels([])
ax1.set_yticklabels([])
# ax1.set_title('b)',y=1,fontsize=30)
ax2.imshow(D[:,:,shot+2],cmap='gray',aspect='auto',vmin=vmin, vmax=vmax)
ax2.set_xticklabels([])
ax2.set_yticklabels([])
# ax2.set_title('c)',y=1,fontsize=30)
ax3.imshow(D[:,:,shot+3],cmap='gray',aspect='auto',vmin=vmin, vmax=vmax)
ax3.set_xticklabels([])
ax3.set_yticklabels([])
# ax3.set_title('d)',y=1,fontsize=30)
ax4.imshow(D[:,:,shot+4],cmap='gray',aspect='auto',vmin=vmin, vmax=vmax)
ax4.set_xlabel('Shot number', fontsize=30)
ax4.set_ylabel('Time sample', fontsize=30)
ax4.tick_params(axis = 'both', which = 'major', labelsize = 20)
# ax4.set_title('e)',y=1,fontsize=30)
ax5.imshow(D[:,:,shot+5],cmap='gray',aspect='auto',vmin=vmin, vmax=vmax)
ax5.set_xticklabels([])
ax5.set_yticklabels([])
# ax5.set_title('f)',y=1,fontsize=30)
ax6.imshow(D[:,:,shot+6],cmap='gray',aspect='auto',vmin=vmin, vmax=vmax)
ax6.set_xticklabels([])
ax6.set_yticklabels([])
# ax6.set_title('g)',y=1,fontsize=30)
ax7.imshow(D[:,:,shot+7],cmap='gray',aspect='auto',vmin=vmin, vmax=vmax)
ax7.set_xticklabels([])
ax7.set_yticklabels([])
# ax7.set_title('h)',y=1,fontsize=30)
# cbar.ax.tick_params(labelsize=12) 

plt.show()
# fig.savefig('3d_rec.eps', format='eps', dpi=100,bbox_inches='tight')

# %%
# relative error
shot = 0

vmin = np.amin(relative[:,:,shot:shot+7])
# vmax = np.amax(relative[:,:,shot:shot+7])
vmax = 0.6
nt,nr,ns = D.shape
code_bar = np.zeros((1,nr))
code_bar_1 = np.zeros((3,nr))
code_bar_2 = np.zeros((3,nr))
code_bar_3 = np.zeros((3,nr))
code_bar_4 = np.zeros((3,nr))
code_bar_5 = np.zeros((3,nr))
code_bar_6 = np.zeros((3,nr))
code_bar_7 = np.zeros((3,nr))
code_bar_8 = np.zeros((3,nr))

code_bar[:,idr] = 1
if code_bar[:,shot]==1:
    code_bar_1[:,idr]=1
if code_bar[:,shot+1]==1:
    code_bar_2[:,idr]=1
if code_bar[:,shot+2]==1:
    code_bar_3[:,idr]=1
if code_bar[:,shot+3]==1:
    code_bar_4[:,idr]=1
if code_bar[:,shot+4]==1:
    code_bar_5[:,idr]=1
if code_bar[:,shot+5]==1:
    code_bar_6[:,idr]=1
if code_bar[:,shot+6]==1:
    code_bar_7[:,idr]=1
if code_bar[:,shot+7]==1:
    code_bar_8[:,idr]=1    
fig = plt.figure(figsize = (30,20))

gs0 = gridspec.GridSpec(1, 4,wspace=0.15)
gs0.update(top=0.97, bottom=0.955)
bar0 = plt.subplot(gs0[0])
bar1 = plt.subplot(gs0[1])
bar2 = plt.subplot(gs0[2])
bar3 = plt.subplot(gs0[3])
bar0.imshow(code_bar_1,cmap='gray',aspect='auto')
bar0.set_title('a)',y=1,fontsize=30)
bar0.set_xticklabels([])
bar0.set_yticklabels([])
bar1.imshow(code_bar_2,cmap='gray',aspect='auto')
bar1.set_title('b)',y=1,fontsize=30)
bar1.set_xticklabels([])
bar1.set_yticklabels([])
bar2.imshow(code_bar_3,cmap='gray',aspect='auto')
bar2.set_title('c)',y=1,fontsize=30)
bar2.set_xticklabels([])
bar2.set_yticklabels([])
bar3.imshow(code_bar_4,cmap='gray',aspect='auto')
bar3.set_title('d)',y=1,fontsize=30)
bar3.set_xticklabels([])
bar3.set_yticklabels([])

gs01 = gridspec.GridSpec(1, 4,wspace=0.15)
gs01.update(top=0.47, bottom=0.455)
bar4 = plt.subplot(gs01[0])
bar5 = plt.subplot(gs01[1])
bar6 = plt.subplot(gs01[2])
bar7 = plt.subplot(gs01[3])
bar4.imshow(code_bar_5,cmap='gray',aspect='auto')
bar4.set_title('e)',y=1,fontsize=30)
bar4.set_xticklabels([])
bar4.set_yticklabels([])
bar5.imshow(code_bar_6,cmap='gray',aspect='auto')
bar5.set_title('f)',y=1,fontsize=30)
bar5.set_xticklabels([])
bar5.set_yticklabels([])
bar6.imshow(code_bar_7,cmap='gray',aspect='auto')
bar6.set_title('g)',y=1,fontsize=30)
bar6.set_xticklabels([])
bar6.set_yticklabels([])
bar7.imshow(code_bar_8,cmap='gray',aspect='auto')
bar7.set_title('h)',y=1,fontsize=30)
bar7.set_xticklabels([])
bar7.set_yticklabels([])


gs1 = gridspec.GridSpec(1, 4)
gs1.update(top=0.95, bottom=0.53,wspace=0.15)
ax0 = plt.subplot(gs1[0])
ax1 = plt.subplot(gs1[1])
ax2 = plt.subplot(gs1[2])
ax3 = plt.subplot(gs1[3])

gs2 = gridspec.GridSpec(1, 4)
gs2.update(top=0.45, bottom=0.03,wspace=0.15)
ax4 = plt.subplot(gs2[0])
ax5 = plt.subplot(gs2[1])
ax6 = plt.subplot(gs2[2])
ax7 = plt.subplot(gs2[3])

ax0.imshow(relative[:,:,shot],cmap='gray',aspect='auto',vmin=vmin, vmax=vmax)
ax0.set_xlabel('Shot number', fontsize=30)
ax0.set_ylabel('Time sample', fontsize=30)
ax0.tick_params(axis = 'both', which = 'major', labelsize = 20)
ax1.imshow(relative[:,:,shot+1],cmap='gray',aspect='auto',vmin=vmin, vmax=vmax)
ax1.set_xticklabels([])
ax1.set_yticklabels([])
# ax1.set_title('b)',y=1,fontsize=30)
ax2.imshow(relative[:,:,shot+2],cmap='gray',aspect='auto',vmin=vmin, vmax=vmax)
ax2.set_xticklabels([])
ax2.set_yticklabels([])
# ax2.set_title('c)',y=1,fontsize=30)
ax3.imshow(relative[:,:,shot+3],cmap='gray',aspect='auto',vmin=vmin, vmax=vmax)
ax3.set_xticklabels([])
ax3.set_yticklabels([])
# ax3.set_title('d)',y=1,fontsize=30)
ax4.imshow(relative[:,:,shot+4],cmap='gray',aspect='auto',vmin=vmin, vmax=vmax)
ax4.set_xlabel('Shot number', fontsize=30)
ax4.set_ylabel('Time sample', fontsize=30)
ax4.tick_params(axis = 'both', which = 'major', labelsize = 20)
# ax4.set_title('e)',y=1,fontsize=30)
ax5.imshow(relative[:,:,shot+5],cmap='gray',aspect='auto',vmin=vmin, vmax=vmax)
ax5.set_xticklabels([])
ax5.set_yticklabels([])
# ax5.set_title('f)',y=1,fontsize=30)
ax6.imshow(relative[:,:,shot+6],cmap='gray',aspect='auto',vmin=vmin, vmax=vmax)
ax6.set_xticklabels([])
ax6.set_yticklabels([])
# ax6.set_title('g)',y=1,fontsize=30)
im = ax7.imshow(relative[:,:,shot+7],cmap='gray',aspect='auto',vmin=vmin, vmax=vmax)
ax7.set_xticklabels([])
ax7.set_yticklabels([])
# ax7.set_title('h)',y=1,fontsize=30)

gsbar = gridspec.GridSpec(1, 1)
gsbar.update(left=0.905, right=0.915,top=0.97, bottom=0.03)
cax = plt.subplot(gsbar[0])
cbar = plt.colorbar(im, cax=cax)
cbar.ax.tick_params(labelsize=20) 
# cbar.ax.tick_params(labelsize=12) 

plt.show()
# fig.savefig('3d_rec_re.eps', format='eps', dpi=100,bbox_inches='tight')
